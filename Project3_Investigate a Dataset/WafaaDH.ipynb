# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('tmdb-movies.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# ...

# %%
df.hist(figsize=(10,8));

# %%
df.revenue.isnull().hist(figsize=(10,8));
df.revenue.hist(figsize=(10,8));
plt.title(" Fill all Null values")
# Out:
# Text(0.5,1,' Fill all Null values')

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 10819
# Data columns (total 21 columns):
# id                      1992 non-null int64
# imdb_id                 1992 non-null object
# popularity              1992 non-null float64
# budget                  1992 non-null int64
# revenue                 1992 non-null int64
# original_title          1992 non-null object
# cast                    1992 non-null object
# homepage                1992 non-null object
# director                1992 non-null object
# tagline                 1992 non-null object
# keywords                1992 non-null object
# overview                1992 non-null object
# runtime                 1992 non-null int64
# genres                  1992 non-null object
# production_companies    1992 non-null object
# release_date            1992 non-null object
# vote_count              1992 non-null int64
# vote_average            1992 non-null float64
# ...

# %%
#1: What is the name and type of the most popularity movi?
most_popu=df['popularity'].max()
most_popu
# Out:
# 32.985763

# %%
most_popu_name=df['original_title'].loc[df['popularity']==most_popu]
most_popu_genres=df['genres'].loc[df['popularity']==most_popu]
most_popu_name,most_popu_genres
# Out:
# (0    Jurassic World
#  Name: original_title, dtype: object,
#  0    Action|Adventure|Science Fiction|Thriller
#  Name: genres, dtype: object)

# %%
#2: What movie that have highest revenues?
higest_revenu_movi=df['revenue'].max()
higest_revenu_movi
# Out:
# 2781505847

# %%
name_higest_revenu_movi=df['original_title'].loc[df['revenue']== higest_revenu_movi]
name_higest_revenu_movi
# Out:
# 1386    Avatar
# Name: original_title, dtype: object

# %%
# lets see the describtion of Avatar movi
df.loc[df['original_title']=='Avatar'].describe()
# Out:
#             id  popularity       budget       revenue  runtime  vote_count  \
# count      1.0    1.000000          1.0  1.000000e+00      1.0         1.0
# mean   19995.0    9.432768  237000000.0  2.781506e+09    162.0      8458.0
# std        NaN         NaN          NaN           NaN      NaN         NaN
# min    19995.0    9.432768  237000000.0  2.781506e+09    162.0      8458.0
# 25%    19995.0    9.432768  237000000.0  2.781506e+09    162.0      8458.0
# 50%    19995.0    9.432768  237000000.0  2.781506e+09    162.0      8458.0
# 75%    19995.0    9.432768  237000000.0  2.781506e+09    162.0      8458.0
# max    19995.0    9.432768  237000000.0  2.781506e+09    162.0      8458.0
#
#        vote_average  release_year    budget_adj   revenue_adj
# count           1.0           1.0  1.000000e+00  1.000000e+00
# mean            7.1        2009.0  2.408869e+08  2.827124e+09
# std             NaN           NaN           NaN           NaN
# ...

# %%
#3: What is the relationship between budjet spend on the movi and How many it runs ?
plt.plot(df['release_year'],df['runtime'] )
plt.legend();
plt.xlabel("release year")
plt.ylabel("number of runtime")
plt.title("relationship between budjet spend and num of runs")
plt.show()
#The chart is confusing because I think there is more than one 
#movie released in the same year, and it is normal that each film has a number of different views.

# %%
#4: lets compere between the number of Horror & Comedy movi
df.loc[df['genres']=='Horror'].count().plot(kind='bar', alpha=0.5, color='blue' ,label='Horror')
df.loc[df['genres']=='Comedy'].count().plot(kind='bar', alpha=0.5, color='red',label='Comedy')
plt.legend();
plt.ylabel("number of movi")
plt.title("Horror Vs Comedy Movi")
plt.show()
#It is clear from this chart that people tend to COMEDY movies more than HORROR movies so the directors resort to making comedies one, because the painting indicates that the number of comedy movies more than horror movies

# %%
#5: The of All movies there type is Horror
df.loc[df['genres']=='Horror'].count()
# Out:
# id                      30
# imdb_id                 30
# popularity              30
# budget                  30
# revenue                 30
# original_title          30
# cast                    30
# homepage                30
# director                30
# tagline                 30
# keywords                30
# overview                30
# runtime                 30
# genres                  30
# production_companies    30
# release_date            30
# vote_count              30
# vote_average            30
# release_year            30
# budget_adj              30
# revenue_adj             30
# dtype: int64

# %%
Horror_movi=df.loc[df['genres']=='Horror']
Name_Horror_movi=Horror_movi['original_title']
Name_Horror_movi
# Out:
# 87                                 Maggie
# 98                             Sinister 2
# 316                     We Are Still Here
# 762                             Annabelle
# 990                           Starry Eyes
# 1022           Wyrmwood: Road Of The Dead
# 1066                       Charlie's Farm
# 1546                         Halloween II
# 1601                      Friday the 13th
# 1763                    The Hills Run Red
# 1770                       The Loved Ones
# 1773     ZMD: Zombies of Mass Destruction
# 2006                               Legion
# 2305                           The Shrine
# 3523                Paranormal Activity 3
# 3844          ChromeSkull: Laid to Rest 2
# 4012                             Darkness
# 4588                             Excision
# 5087                House of 1000 Corpses
# 5475                            Evil Dead
# 5529                                 Mama
# 5978                            Nailbiter
# ...

# %%
#6: Let 's see every dirctor how many film make?
Duplicate_director=df.loc[df['director'].duplicated()==True]
e=Duplicate_director.groupby('director').count()
e
# Out:
#                                 id  imdb_id  popularity  budget  revenue  \
# director
# Adam Green                       1        1           1       1        1
# Adam McKay                       2        2           2       2        2
# Adam Shankman                    3        3           3       3        3
# Alan Taylor                      1        1           1       1        1
# Alejandro GonzÃ¡lez IÃ±Ã¡rritu   1        1           1       1        1
# Alex Gibney                      1        1           1       1        1
# Alex Kendrick                    3        3           3       3        3
# Alex Proyas                      1        1           1       1        1
# Alexander Payne                  1        1           1       1        1
# Alexandre Aja                    1        1           1       1        1
# Alfonso CuarÃ³n                  1        1           1       1        1
# Allen Coulter                    1        1           1       1        1
# ...
